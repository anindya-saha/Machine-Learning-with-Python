# %% [markdown]
# #Document retrieval from wikipedia data
#
# #Fire up GraphLab Create

# %%
import graphlab

# %%
people = graphlab.SFrame('people_wiki.gl/')
# Out:
# [INFO] This non-commercial license of GraphLab Create is assigned to anindya.saha@tamu.eduand will expire on September 21, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-12296 - Server binary: C:\Users\Anindya\AppData\Local\Dato\Dato Launcher\lib\site-packages\graphlab\unity_server.exe - Server log: C:\Users\Anindya\AppData\Local\Temp\graphlab_server_1443546904.log.0
# [INFO] GraphLab Server Version: 1.6.1

# %%
people.head()
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
#
# Rows: 10
#
# Data:
# +-------------------------------+---------------------+
# |              URI              |         name        |
# +-------------------------------+---------------------+
# | <http://dbpedia.org/resour... |    Digby Morrell    |
# | <http://dbpedia.org/resour... |    Alfred J. Lewy   |
# | <http://dbpedia.org/resour... |    Harpdog Brown    |
# | <http://dbpedia.org/resour... | Franz Rottensteiner |
# | <http://dbpedia.org/resour... |        G-Enka       |
# | <http://dbpedia.org/resour... |    Sam Henderson    |
# | <http://dbpedia.org/resour... |    Aaron LaCrate    |
# | <http://dbpedia.org/resour... |   Trevor Ferguson   |
# | <http://dbpedia.org/resour... |     Grant Nelson    |
# | <http://dbpedia.org/resour... |     Cathy Caruth    |
# +-------------------------------+---------------------+
# +-------------------------------+
# |              text             |
# +-------------------------------+
# ...

# %% [markdown]
# #Explore the dataset and checkout the text it contains
#
# ##Exploring the entry for singer Elton John

# %%
john = people[people['name'] == 'Elton John']

# %%
john
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
#
# Rows: Unknown
#
# Data:
# +-------------------------------+------------+-------------------------------+
# |              URI              |    name    |              text             |
# +-------------------------------+------------+-------------------------------+
# | <http://dbpedia.org/resour... | Elton John | sir elton hercules john cb... |
# +-------------------------------+------------+-------------------------------+
# [? rows x 3 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use len(sf) to force materialization.

# %%
john['text']
# Out:
# dtype: str
# Rows: ?
# ...

# %% [markdown]
# #Get the word counts for Elton John article

# %%
john['word_count'] = graphlab.text_analytics.count_words(john['text'])

# %%
print john['word_count']
# Out:
# [{'all': 1L, 'six': 1L, 'producer': 1L, 'heavily': 1L, 'over': 2L, 'named': 1L, 'fifty': 1L, 'four': 1L, 'openly': 1L, 'including': 1L, 'highestprofile': 1L, 'years': 1L, 'its': 2L, 'impact': 1L, 'westminster': 1L, '27': 1L, '21': 2L, 'wed': 1L, 'had': 1L, '1947': 1L, 'abbey': 1L, 'winning': 1L, 'late': 1L, 'to': 4L, 'commander': 1L, 'about': 1L, 'born': 1L, '2014': 1L, 'as': 2L, 'has': 9L, '2013': 1L, 'his': 4L, 'march': 1L, 'than': 3L, 'song': 1L, 'songwriter': 2L, 'continues': 1L, 'records': 1L, 'five': 1L, 'occasional': 1L, 'they': 1L, 'inception': 1L, 'world': 1L, 'brit': 1L, 'him': 3L, 'datein': 1L, 'hall': 2L, 'fivedecade': 1L, 'knighthood': 1L, 'bestselling': 2L, 'artist': 1L, 'be': 1L, '1996': 1L, 'list': 1L, 'roll': 2L, 'hercules': 1L, 'announced': 1L, 'rock': 2L, 'become': 1L, 'bernie': 1L, 'outstanding': 1L, 'england': 1L, 'composer': 1L, 'queens': 1L, 'foundation': 2L, 'diana': 1L, 'globe': 1L, 'artists': 2L, 'culture': 1L, 'been': 3L, '49': 1L, 'year': 1L, 'billboard': 
# ...

# %% [markdown]
# ##Sort the word counts for the Elton John article
# ###Turning dictonary of word counts into a table

# %%
john_word_count_table = john[['word_count']].stack('word_count', new_column_name = ['word', 'count'])

# %% [markdown]
# ###Sorting the word counts to show most common words at the top

# %%
john_word_count_table.head()
# Out:
# Columns:
# 	word	str
# 	count	int
#
# Rows: 10
#
# Data:
# +-----------+-------+
# |    word   | count |
# +-----------+-------+
# | movements |   1   |
# |   social  |   1   |
# |  champion |   1   |
# |    wed    |   1   |
# |   legal   |   1   |
# |   became  |   1   |
# |   after   |   1   |
# |    2005   |   1   |
# |  december |   2   |
# |  furnish  |   2   |
# +-----------+-------+
# [10 rows x 2 columns]

# %%
john_word_count_table.sort('count', ascending = False)
# Out:
# Columns:
# 	word	str
# 	count	int
#
# Rows: 255
#
# Data:
# +-------+-------+
# |  word | count |
# +-------+-------+
# |  the  |   27  |
# |   in  |   18  |
# |  and  |   15  |
# |   of  |   13  |
# |   a   |   10  |
# |  has  |   9   |
# |   he  |   7   |
# |  john |   7   |
# |   on  |   6   |
# | since |   5   |
# +-------+-------+
# [255 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# Most common words include uninformative words like "the", "in", "and",...

# %% [markdown]
# #Compute TF-IDF for the corpus
#
# To give more weight to informative words, we weigh them by their TF-IDF scores.

# %%
people['word_count'] = graphlab.text_analytics.count_words(people['text'])

# %%
people.head()
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
# 	word_count	dict
#
# Rows: 10
#
# Data:
# +-------------------------------+---------------------+
# |              URI              |         name        |
# +-------------------------------+---------------------+
# | <http://dbpedia.org/resour... |    Digby Morrell    |
# | <http://dbpedia.org/resour... |    Alfred J. Lewy   |
# | <http://dbpedia.org/resour... |    Harpdog Brown    |
# | <http://dbpedia.org/resour... | Franz Rottensteiner |
# | <http://dbpedia.org/resour... |        G-Enka       |
# | <http://dbpedia.org/resour... |    Sam Henderson    |
# | <http://dbpedia.org/resour... |    Aaron LaCrate    |
# | <http://dbpedia.org/resour... |   Trevor Ferguson   |
# | <http://dbpedia.org/resour... |     Grant Nelson    |
# | <http://dbpedia.org/resour... |     Cathy Caruth    |
# +-------------------------------+---------------------+
# +-------------------------------+-------------------------------+
# ...

# %%
tfidf = graphlab.text_analytics.tf_idf(people['word_count'])

# %%
tfidf
# Out:
# Columns:
# 	docs	dict
#
# Rows: 59071
#
# Data:
# +-------------------------------+
# |              docs             |
# +-------------------------------+
# | {'since': 1.45537671730804... |
# | {'precise': 6.443200606955... |
# | {'just': 2.700729968710864... |
# | {'all': 1.6431112434912472... |
# | {'legendary': 4.2808562943... |
# | {'now': 1.96695239252401, ... |
# | {'exclusive': 10.455187230... |
# | {'taxi': 6.052021456094502... |
# | {'houston': 3.935505942157... |
# | {'phenomenon': 5.750053426... |
# +-------------------------------+
# [59071 rows x 1 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
people['tfidf'] = tfidf['docs']

# %%
people.head()
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
# 	word_count	dict
# 	tfidf	dict
#
# Rows: 10
#
# Data:
# +-------------------------------+---------------------+
# |              URI              |         name        |
# +-------------------------------+---------------------+
# | <http://dbpedia.org/resour... |    Digby Morrell    |
# | <http://dbpedia.org/resour... |    Alfred J. Lewy   |
# | <http://dbpedia.org/resour... |    Harpdog Brown    |
# | <http://dbpedia.org/resour... | Franz Rottensteiner |
# | <http://dbpedia.org/resour... |        G-Enka       |
# | <http://dbpedia.org/resour... |    Sam Henderson    |
# | <http://dbpedia.org/resour... |    Aaron LaCrate    |
# | <http://dbpedia.org/resour... |   Trevor Ferguson   |
# | <http://dbpedia.org/resour... |     Grant Nelson    |
# | <http://dbpedia.org/resour... |     Cathy Caruth    |
# +-------------------------------+---------------------+
# +-------------------------------+-------------------------------+
# ...

# %% [markdown]
# ##Examine the TF-IDF for the Elton John article

# %%
john = people[people['name'] == 'Elton John']

# %%
john[['tfidf']].stack('tfidf', new_column_name=['word','tfidf']).sort('tfidf', ascending=False)
# Out:
# Columns:
# 	word	str
# 	tfidf	float
#
# Rows: 255
#
# Data:
# +---------------+---------------+
# |      word     |     tfidf     |
# +---------------+---------------+
# |    furnish    |  18.38947184  |
# |     elton     |  17.48232027  |
# |   billboard   | 17.3036809575 |
# |      john     | 13.9393127924 |
# |  songwriters  |  11.250406447 |
# |  overallelton | 10.9864953892 |
# | tonightcandle | 10.9864953892 |
# |    19702000   | 10.2933482087 |
# |   fivedecade  | 10.2933482087 |
# |      aids     |  10.262846934 |
# +---------------+---------------+
# [255 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# Comparing the top words according to word counts to TF-IDF for Elton John:
#
# 3 most popular words in his articles with highest word counts are: the, in, and
#
# 3 most popular words in his articles with highest TF-IDF are: furnish, elton, billboard
#
# Clearly. these results illustrate why TF-IDF is useful for finding important words.

# %% [markdown]
# #Manually compute distances between a few people
#
# Let's manually compare the distances between the articles for a few famous people.

# %%
beckham = people[people['name'] == 'Victoria Beckham']

# %%
mccartney = people[people['name'] == 'Paul McCartney']

# %% [markdown]
# ##Is Elton John closer to Paul McCartney than to Victoria Beckham?
#
# We will use cosine distance, which is given by
#
# (1-cosine_similarity)
#
# and find that the article about singer Elton John is closer to the one about singer Paul McCartney than that of model and singer Victoria Beckham.

# %%
graphlab.distances.cosine(john['tfidf'][0],mccartney['tfidf'][0])
# Out:
# 0.8250310029221779

# %%
graphlab.distances.cosine(john['tfidf'][0],beckham['tfidf'][0])
# Out:
# 0.9567006376655429

# %% [markdown]
# ## Build a nearest neighbor model based on word count for document retrieval
#
# We now create a nearest-neighbors model and apply it to document retrieval.

# %%
knn_word_count_model = graphlab.nearest_neighbors.create(people, features=['word_count'], label='name', distance='cosine')

# %% [markdown]
# ## Build a nearest neighbor model based on tfidf for document retrieval
#
# We now create a nearest-neighbors model and apply it to document retrieval.

# %%
knn_tfidf_model = graphlab.nearest_neighbors.create(people, features=['tfidf'], label='name', distance='cosine')

# %% [markdown]
# ## Applying the nearest-neighbors model for retrieval

# %% [markdown]
# ###Who is closest to Elton John using word count features?

# %%
knn_word_count_model.query(john)
# Out:
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-------------------+-------------------+------+
# | query_label |  reference_label  |      distance     | rank |
# +-------------+-------------------+-------------------+------+
# |      0      |     Elton John    | 2.22044604925e-16 |  1   |
# |      0      |   Cliff Richard   |   0.16142415259   |  2   |
# |      0      |   Sandro Petrone  |   0.16822542751   |  3   |
# |      0      |    Rod Stewart    |   0.168327165587  |  4   |
# |      0      | Malachi O'Doherty |   0.177315545979  |  5   |
# +-------------+-------------------+-------------------+------+
# [5 rows x 4 columns]

# %% [markdown]
# ###Who is closest to Elton John using tfidf features?

# %%
knn_tfidf_model.query(john)
# Out:
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+------------------+--------------------+------+
# | query_label | reference_label  |      distance      | rank |
# +-------------+------------------+--------------------+------+
# |      0      |    Elton John    | -2.22044604925e-16 |  1   |
# |      0      |   Rod Stewart    |   0.717219667893   |  2   |
# |      0      |  George Michael  |   0.747600998969   |  3   |
# |      0      | Sting (musician) |   0.747671954431   |  4   |
# |      0      |   Phil Collins   |   0.75119324879    |  5   |
# +-------------+------------------+--------------------+------+
# [5 rows x 4 columns]

# %% [markdown]
# ###Who is closest to Victoria Beckham using word count features?

# %%
knn_word_count_model.query(beckham)
# Out:
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+--------------------------+--------------------+------+
# | query_label |     reference_label      |      distance      | rank |
# +-------------+--------------------------+--------------------+------+
# |      0      |     Victoria Beckham     | -2.22044604925e-16 |  1   |
# |      0      | Mary Fitzgerald (artist) |   0.207307036115   |  2   |
# |      0      |      Adrienne Corri      |   0.214509782788   |  3   |
# |      0      |     Beverly Jane Fry     |   0.217466468741   |  4   |
# |      0      |      Raman Mundair       |   0.217695474992   |  5   |
# +-------------+--------------------------+--------------------+------+
# [5 rows x 4 columns]

# %% [markdown]
# ###Who is closest to Victoria Beckham using tfidf features?

# %%
knn_tfidf_model.query(beckham)
# Out:
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+---------------------+-------------------+------+
# | query_label |   reference_label   |      distance     | rank |
# +-------------+---------------------+-------------------+------+
# |      0      |   Victoria Beckham  | 1.11022302463e-16 |  1   |
# |      0      |    David Beckham    |   0.548169610263  |  2   |
# |      0      | Stephen Dow Beckham |   0.784986706828  |  3   |
# |      0      |        Mel B        |   0.809585523409  |  4   |
# |      0      |    Caroline Rush    |   0.819826422919  |  5   |
# +-------------+---------------------+-------------------+------+
# [5 rows x 4 columns]
