# %% [markdown]
# # Problem Statement
#
# [Urban Sound Classification](https://datahack.analyticsvidhya.com/contest/practice-problem-urban-sound-classification/): Classify Urban Sound Clips into different classes. This notebook is based on [https://www.analyticsvidhya.com/blog/2017/08/audio-voice-processing-deep-learning/#comment-143974]
#
# The dataset contains 8732 sound excerpts (<=4s) of urban sounds from 10 classes, namely:
#
# - air conditioner
# - car horn
# - children playing
# - dog bark
# - drilling
# - engine idling
# - gun shot
# - jackhammer
# - siren
# - street music

# %%
import os

import numpy as np
import pandas as pd

import librosa
import librosa.display

import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# to make this notebook's output stable across runs
np.random.seed(42)
random_state = 42

# %%
data_dir = "C:/urban-sound-challenge/"

# %% [markdown]
# ## Prepare Data for Machine Learning: Load audio files and extract features

# %% [markdown]
# We already prepared the data in our urban-sound-classification-exploration notebook.

# %%
valid_pred_mfcc802L_df = pd.read_csv(os.path.join(data_dir, "valid_pred_mfcc802L.csv"))
valid_pred_mel_df = pd.read_csv(os.path.join(data_dir, "valid_pred_mel.csv"))
valid_pred_contrast_df = pd.read_csv(os.path.join(data_dir, "valid_pred_contrast.csv"))
valid_pred_chroma_df = pd.read_csv(os.path.join(data_dir, "valid_pred_chroma.csv"))

valid_df = pd.read_csv(os.path.join(data_dir, "valid_df.csv"))

# %%
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()
lb.fit(valid_df['Class'])
# Out:
# LabelEncoder()

# %%
lb.classes_
# Out:
# array(['air_conditioner', 'car_horn', 'children_playing', 'dog_bark',
#        'drilling', 'engine_idling', 'gun_shot', 'jackhammer', 'siren',
#        'street_music'], dtype=object)

# %%
all_valid_pred_df = (valid_pred_mfcc802L_df
                     .join(valid_pred_mel_df)
                     .join(valid_pred_contrast_df)
                     .join(valid_pred_chroma_df)
                     .join(valid_df['Class']))

# %%
all_valid_pred_df.iloc[0:80]
# Out:
#        pred_mfcc802L          pred_mel     pred_contrast       pred_chroma  \
# 0           drilling        jackhammer     engine_idling   air_conditioner
# 1         jackhammer        jackhammer        jackhammer        jackhammer
# 2           car_horn          car_horn  children_playing          car_horn
# 3              siren        jackhammer        jackhammer          gun_shot
# 4      engine_idling     engine_idling   air_conditioner        jackhammer
# 5           car_horn          car_horn      street_music          drilling
# 6           drilling          drilling   air_conditioner          gun_shot
# 7           dog_bark          dog_bark          dog_bark  children_playing
# 8         jackhammer        jackhammer        jackhammer        jackhammer
# 9       street_music      street_music  children_playing      street_music
# 10  children_playing          dog_bark             siren  children_playing
# 11        jackhammer        jackhammer        jackhammer        jackhammer
# 12          car_horn          car_horn          car_horn          car_horn
# 13  children_playing  children_playing  children_playing  children_playing
# 14  children_playing      street_music      street_music          dog_bark
# 15   air_conditioner   air_conditioner        jackhammer   air_conditioner
# 16   air_conditioner   air_conditioner   air_conditioner   air_conditioner
# 17          drilling          drilling          drilling          drilling
# 18          dog_bark          dog_bark  children_playing          drilling
# 19        jackhammer        jackhammer          car_horn     engine_idling
# 20        jackhammer        jackhammer        jackhammer   air_conditioner
# 21  children_playing  children_playing  children_playing  children_playing
# 22          drilling          drilling   air_conditioner        jackhammer
# 23  children_playing  children_playing        jackhammer  children_playing
# 24          car_horn          car_horn          car_horn          car_horn
# 25     engine_idling     engine_idling     engine_idling          gun_shot
# 26          drilling          drilling     engine_idling          drilling
# 27             siren             siren          drilling             siren
# 28   air_conditioner   air_conditioner   air_conditioner   air_conditioner
# 29          drilling          drilling  children_playing   air_conditioner
# ..               ...               ...               ...               ...
# 50          drilling          drilling          drilling     engine_idling
# 51     engine_idling   air_conditioner        jackhammer          gun_shot
# 52     engine_idling     engine_idling     engine_idling     engine_idling
# 53  children_playing  children_playing          dog_bark      street_music
# 54          dog_bark          dog_bark          car_horn          dog_bark
# 55          dog_bark          dog_bark  children_playing  children_playing
# 56  children_playing          drilling  children_playing      street_music
# 57          drilling          drilling             siren  children_playing
# 58        jackhammer  children_playing        jackhammer        jackhammer
# 59          car_horn          car_horn          car_horn          car_horn
# 60             siren             siren  children_playing  children_playing
# 61     engine_idling     engine_idling   air_conditioner        jackhammer
# 62     engine_idling     engine_idling     engine_idling     engine_idling
# 63  children_playing  children_playing          drilling  children_playing
# 64          drilling          drilling          drilling          drilling
# 65     engine_idling     engine_idling     engine_idling        jackhammer
# 66             siren             siren          dog_bark             siren
# 67        jackhammer        jackhammer        jackhammer        jackhammer
# 68     engine_idling     engine_idling     engine_idling   air_conditioner
# 69          drilling          drilling  children_playing   air_conditioner
# 70          gun_shot          gun_shot        jackhammer          gun_shot
# 71          dog_bark          dog_bark          dog_bark  children_playing
# 72  children_playing  children_playing   air_conditioner  children_playing
# 73          dog_bark          dog_bark          car_horn          car_horn
# 74     engine_idling     engine_idling     engine_idling     engine_idling
# 75        jackhammer        jackhammer        jackhammer     engine_idling
# 76      street_music      street_music          drilling          dog_bark
# 77        jackhammer        jackhammer        jackhammer          gun_shot
# 78   air_conditioner  children_playing  children_playing  children_playing
# 79             siren             siren             siren             siren
#
#                Class
# 0           drilling
# 1       street_music
# 2           car_horn
# 3           dog_bark
# 4      engine_idling
# 5           car_horn
# 6           drilling
# 7           dog_bark
# 8         jackhammer
# 9       street_music
# 10  children_playing
# 11        jackhammer
# 12          car_horn
# 13      street_music
# 14      street_music
# 15   air_conditioner
# 16   air_conditioner
# 17          drilling
# 18          dog_bark
# 19        jackhammer
# 20        jackhammer
# 21  children_playing
# 22          drilling
# 23          dog_bark
# 24          car_horn
# 25     engine_idling
# 26          drilling
# 27             siren
# 28   air_conditioner
# 29          drilling
# ..               ...
# 50          drilling
# 51     engine_idling
# 52     engine_idling
# 53      street_music
# 54          dog_bark
# 55          dog_bark
# 56      street_music
# 57          drilling
# 58        jackhammer
# 59          car_horn
# 60             siren
# 61     engine_idling
# 62     engine_idling
# 63  children_playing
# 64          drilling
# 65     engine_idling
# 66             siren
# 67        jackhammer
# 68     engine_idling
# 69          drilling
# 70          gun_shot
# 71          dog_bark
# 72  children_playing
# 73          dog_bark
# 74     engine_idling
# 75        jackhammer
# 76      street_music
# 77        jackhammer
# 78  children_playing
# 79             siren
#
# [80 rows x 5 columns]

# %%
all_valid_pred_df.apply(lambda x: lb.transform(x)).corr()
# Out:
#                pred_mfcc802L  pred_mel  pred_contrast  pred_chroma     Class
# pred_mfcc802L       1.000000  0.644135       0.373482     0.491699  0.826257
# pred_mel            0.644135  1.000000       0.334832     0.437221  0.651152
# pred_contrast       0.373482  0.334832       1.000000     0.265848  0.361457
# pred_chroma         0.491699  0.437221       0.265848     1.000000  0.501023
# Class               0.826257  0.651152       0.361457     0.501023  1.000000

# %%
accu_df = pd.DataFrame([[len(all_valid_pred_df[(all_valid_pred_df[feat] == cat) & (all_valid_pred_df['Class'] == cat)]) for cat in lb.classes_] for feat in ['pred_mfcc802L', 'pred_mel', 'pred_contrast', 'pred_chroma', 'Class']])
accu_df.columns = lb.classes_
accu_df.index = ['accu_mfcc802L', 'accu_mel', 'accu_contrast', 'accu_chroma', 'total']
accu_df
# Out:
#                air_conditioner  car_horn  children_playing  dog_bark  \
# accu_mfcc802L              146        64               134       103
# accu_mel                   138        52               108        97
# accu_contrast               63        44                92        69
# accu_chroma                 77        56               119        58
# total                      150        77               150       150
#
#                drilling  engine_idling  gun_shot  jackhammer  siren  \
# accu_mfcc802L       143            148        37         165    145
# accu_mel            112            114        35         153    102
# accu_contrast        64             83         1         126     78
# accu_chroma          39             67        38         109    111
# total               150            156        57         167    152
#
#                street_music
# accu_mfcc802L           103
# accu_mel                 78
# accu_contrast            31
# accu_chroma              80
# total                   150

# %%
import seaborn as sns
plt.figure(figsize=(10, 4))
sns.heatmap(accu_df, cmap='viridis');

# %%
all_valid_pred_df[all_valid_pred_df['pred_mfcc802L'] != all_valid_pred_df['Class']]
# Out:
#          pred_mfcc802L          pred_mel     pred_contrast       pred_chroma  \
# 1           jackhammer        jackhammer        jackhammer        jackhammer
# 3                siren        jackhammer        jackhammer          gun_shot
# 13    children_playing  children_playing  children_playing  children_playing
# 14    children_playing      street_music      street_music          dog_bark
# 23    children_playing  children_playing        jackhammer  children_playing
# 35               siren          dog_bark  children_playing  children_playing
# 37    children_playing     engine_idling          dog_bark          dog_bark
# 38    children_playing      street_music  children_playing          dog_bark
# 41    children_playing      street_music      street_music  children_playing
# 48    children_playing  children_playing          dog_bark          drilling
# 53    children_playing  children_playing          dog_bark      street_music
# 56    children_playing          drilling  children_playing      street_music
# 78     air_conditioner  children_playing  children_playing  children_playing
# 83               siren          dog_bark          dog_bark          dog_bark
# 90     air_conditioner   air_conditioner          drilling  children_playing
# 105       street_music  children_playing  children_playing             siren
# 108   children_playing          dog_bark          dog_bark          dog_bark
# 125       street_music  children_playing  children_playing   air_conditioner
# 140              siren             siren             siren             siren
# 150   children_playing          car_horn          drilling      street_music
# 169         jackhammer        jackhammer   air_conditioner          gun_shot
# 171   children_playing             siren  children_playing             siren
# 176         jackhammer   air_conditioner     engine_idling          gun_shot
# 195           drilling          dog_bark        jackhammer          dog_bark
# 196   children_playing      street_music          drilling      street_music
# 205    air_conditioner      street_music  children_playing          drilling
# 208   children_playing   air_conditioner   air_conditioner  children_playing
# 210   children_playing  children_playing          dog_bark  children_playing
# 220   children_playing          car_horn  children_playing          dog_bark
# 227      engine_idling   air_conditioner     engine_idling          dog_bark
# ...                ...               ...               ...               ...
# 1162   air_conditioner   air_conditioner          drilling        jackhammer
# 1171          dog_bark          dog_bark          car_horn             siren
# 1189          dog_bark      street_music          drilling          dog_bark
# 1211          drilling          drilling        jackhammer     engine_idling
# 1212  children_playing   air_conditioner          drilling  children_playing
# 1226  children_playing          drilling        jackhammer     engine_idling
# 1238          dog_bark          car_horn          car_horn          car_horn
# 1239  children_playing  children_playing          drilling          drilling
# 1240          dog_bark          gun_shot  children_playing   air_conditioner
# 1241  children_playing  children_playing  children_playing          dog_bark
# 1242  children_playing  children_playing        jackhammer  children_playing
# 1243             siren  children_playing          drilling          dog_bark
# 1244          dog_bark          dog_bark  children_playing          car_horn
# 1248          dog_bark      street_music      street_music          dog_bark
# 1263  children_playing  children_playing        jackhammer  children_playing
# 1265          dog_bark          gun_shot        jackhammer          gun_shot
# 1266  children_playing      street_music      street_music      street_music
# 1272             siren        jackhammer  children_playing  children_playing
# 1276  children_playing   air_conditioner  children_playing        jackhammer
# 1278  children_playing  children_playing          dog_bark          dog_bark
# 1300          dog_bark          dog_bark          car_horn             siren
# 1301  children_playing   air_conditioner          drilling  children_playing
# 1307             siren          car_horn          drilling   air_conditioner
# 1308  children_playing   air_conditioner   air_conditioner     engine_idling
# 1310   air_conditioner     engine_idling          drilling        jackhammer
# 1312          dog_bark      street_music      street_music             siren
# 1316  children_playing  children_playing          dog_bark  children_playing
# 1328  children_playing  children_playing          dog_bark          dog_bark
# 1344  children_playing  children_playing        jackhammer          gun_shot
# 1354  children_playing  children_playing      street_music             siren
#
#                  Class
# 1         street_music
# 3             dog_bark
# 13        street_music
# 14        street_music
# 23            dog_bark
# 35            dog_bark
# 37        street_music
# 38        street_music
# 41        street_music
# 48            dog_bark
# 53        street_music
# 56        street_music
# 78    children_playing
# 83            dog_bark
# 90        street_music
# 105   children_playing
# 108       street_music
# 125           car_horn
# 140   children_playing
# 150           drilling
# 169           dog_bark
# 171              siren
# 176    air_conditioner
# 195           dog_bark
# 196       street_music
# 205           dog_bark
# 208       street_music
# 210       street_music
# 220           dog_bark
# 227       street_music
# ...                ...
# 1162     engine_idling
# 1171             siren
# 1189      street_music
# 1211          car_horn
# 1212      street_music
# 1226          gun_shot
# 1238          car_horn
# 1239          drilling
# 1240          gun_shot
# 1241          dog_bark
# 1242          gun_shot
# 1243          dog_bark
# 1244          car_horn
# 1248      street_music
# 1263      street_music
# 1265          gun_shot
# 1266      street_music
# 1272  children_playing
# 1276      street_music
# 1278          dog_bark
# 1300             siren
# 1301      street_music
# 1307     engine_idling
# 1308          dog_bark
# 1310     engine_idling
# 1312      street_music
# 1316          dog_bark
# 1328          dog_bark
# 1344          car_horn
# 1354      street_music
#
# [171 rows x 5 columns]
